# %% [markdown]
# <a href="https://colab.research.google.com/github/tarnilok/Assignments-in-Clarusway/blob/main/C_8255_Assignment_008_9_(Letters_Count).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sentence = input("Enter a sentence, please : ").strip()
sentence = sentence.lower()
dict = {}
for i in sentence :
    counter = sentence.count(i)
    dict[i] = counter
print(dict)
# Out:
# Enter a sentence, please : Which path should I choose?
# {'w': 1, 'h': 5, 'i': 2, 'c': 2, ' ': 4, 'p': 1, 'a': 1, 't': 1, 's': 2, 'o': 3, 'u': 1, 'l': 1, 'd': 1, 'e': 1, '?': 1}
